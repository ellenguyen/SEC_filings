# %% [markdown]
# ## Import libraries

# %%
from bs4 import BeautifulSoup
import re, os, logging, time, argparse, unicodedata, html5lib, requests
import pandas as pd
import numpy as np
from openpyxl import Workbook
from datetime import datetime

# %% [markdown]
# ## Helper functions

# %% [markdown]
# 1. **parse_and_trim()** -> Parses and trims HTML content by removing all attributes from HTML tags and removing line break tags from the content
# 2. **remove_multiple_spaces()** -> Replace multiple spaces with a single space in a string
# 3. **find_qtr_date()** -> Extract and format a quarterly date from text content

# %%
def parse_and_trim(content, content_type):
    if content_type == 'HTML':
        soup = BeautifulSoup(content, 'html.parser')
    else:
        soup = BeautifulSoup(content, 'html.parser')

    for tag in soup.recursiveChildGenerator():
        try:
            tag.attrs = None
        except AttributeError:
            pass

    for linebreak in soup.find_all('br'):
        linebreak.extract()

    return soup

# %%
def remove_multiple_spaces(string):
    pattern = r'\s+'
    replaced_string = re.sub(pattern, ' ', string)
    return replaced_string

# %%
def find_qrt_date(content):
    qtr_date = content.find_all(string=re.compile(
        r'for\s+(the\s+)?(fiscal\s+)?year\s+ended\s+|for\s+the\s+quarter\s+ended\s+|for\s+the\s+quarterly\s+period\s+ended\s+', re.IGNORECASE))
    qtr_match = re.search(
        r'([A-Za-z]+)\s+(\d{1,2}),\s+(\d{4})', qtr_date[0].replace('\n', ''))
    print(qtr_date[0])
    if qtr_match is None:
        qtr_match = re.search(
            r'([A-Za-z]+) (\d{1,2}), (\d{4})', qtr_date[1])
    if qtr_match:
        return remove_multiple_spaces(str(qtr_match.group()))
    else:
        return None

# %% [markdown]
# ## Preprocess filing links

# %%
# Assign headers
headers = {
    'User-Agent': 'Blue Owl Capital Corp II'
}

# Extract to a dataframe
df = pd.read_csv("/kaggle/input/scraping-url/scraping_url.csv")
df.head()
# Out:
#    Unnamed: 0       accessionNumber  filingDate  reportDate  \
# 0           0  0001655887-24-000017  2024-05-13  2024-03-31
# 1           1  0001655887-24-000009  2024-03-07  2023-12-31
# 2           2  0001655887-23-000048  2023-11-09  2023-09-30
# 3           3  0001655887-23-000039  2023-08-10  2023-06-30
# 4           4  0001655887-23-000025  2023-05-11  2023-03-31
#
#          acceptanceDateTime  act  form fileNumber  filmNumber  items  \
# 0  2024-05-10T17:40:30.000Z   34  10-Q  814-01219    24936212    NaN
# 1  2024-03-06T19:19:00.000Z   34  10-K  814-01219    24727699    NaN
# 2  2023-11-09T16:58:33.000Z   34  10-Q  814-01219   231393518    NaN
# 3  2023-08-10T17:14:29.000Z   34  10-Q  814-01219   231160654    NaN
# 4  2023-05-11T16:06:55.000Z   34  10-Q  814-01219    23910979    NaN
#
#        size  isXBRL  isInlineXBRL    primaryDocument primaryDocDescription  \
# 0  28055386       1             1  obdc-20240331.htm                  10-Q
# 1  35559661       1             1  obdc-20231231.htm                  10-K
# 2  28991189       1             1  obdc-20230930.htm                  10-Q
# 3  27739370       1             1  obdc-20230630.htm                  10-Q
# 4  46704697       1             1  orcc-20230331.htm                  10-Q
#
#                                             fileLink  \
# 0  https://www.sec.gov/Archives/edgar/data/165588...
# 1  https://www.sec.gov/Archives/edgar/data/165588...
# 2  https://www.sec.gov/Archives/edgar/data/165588...
# 3  https://www.sec.gov/Archives/edgar/data/165588...
# 4  https://www.sec.gov/Archives/edgar/data/165588...
#
#                                          txtFileLink
# 0  https://www.sec.gov/Archives/edgar/data/165588...
# 1  https://www.sec.gov/Archives/edgar/data/165588...
# 2  https://www.sec.gov/Archives/edgar/data/165588...
# 3  https://www.sec.gov/Archives/edgar/data/165588...
# 4  https://www.sec.gov/Archives/edgar/data/165588...

# %%
# Drops all the amendment filing
# Keep only Qs & Ks
df = df.drop(df[df['primaryDocDescription'].str.contains(
    'amendment', case=False)].index).reset_index(drop=True)
df['Reporting date'] = pd.to_datetime(df['reportDate'])
df.head()
# Out:
#    Unnamed: 0       accessionNumber  filingDate  reportDate  \
# 0           0  0001655887-24-000017  2024-05-13  2024-03-31
# 1           1  0001655887-24-000009  2024-03-07  2023-12-31
# 2           2  0001655887-23-000048  2023-11-09  2023-09-30
# 3           3  0001655887-23-000039  2023-08-10  2023-06-30
# 4           4  0001655887-23-000025  2023-05-11  2023-03-31
#
#          acceptanceDateTime  act  form fileNumber  filmNumber  items  \
# 0  2024-05-10T17:40:30.000Z   34  10-Q  814-01219    24936212    NaN
# 1  2024-03-06T19:19:00.000Z   34  10-K  814-01219    24727699    NaN
# 2  2023-11-09T16:58:33.000Z   34  10-Q  814-01219   231393518    NaN
# 3  2023-08-10T17:14:29.000Z   34  10-Q  814-01219   231160654    NaN
# 4  2023-05-11T16:06:55.000Z   34  10-Q  814-01219    23910979    NaN
#
#        size  isXBRL  isInlineXBRL    primaryDocument primaryDocDescription  \
# 0  28055386       1             1  obdc-20240331.htm                  10-Q
# 1  35559661       1             1  obdc-20231231.htm                  10-K
# 2  28991189       1             1  obdc-20230930.htm                  10-Q
# 3  27739370       1             1  obdc-20230630.htm                  10-Q
# 4  46704697       1             1  orcc-20230331.htm                  10-Q
#
#                                             fileLink  \
# 0  https://www.sec.gov/Archives/edgar/data/165588...
# 1  https://www.sec.gov/Archives/edgar/data/165588...
# 2  https://www.sec.gov/Archives/edgar/data/165588...
# 3  https://www.sec.gov/Archives/edgar/data/165588...
# 4  https://www.sec.gov/Archives/edgar/data/165588...
#
#                                          txtFileLink Reporting date
# 0  https://www.sec.gov/Archives/edgar/data/165588...     2024-03-31
# 1  https://www.sec.gov/Archives/edgar/data/165588...     2023-12-31
# 2  https://www.sec.gov/Archives/edgar/data/165588...     2023-09-30
# 3  https://www.sec.gov/Archives/edgar/data/165588...     2023-06-30
# 4  https://www.sec.gov/Archives/edgar/data/165588...     2023-03-31

# %%
# Convert to datetime format
date_columns = ['filingDate', 'reportDate']
for col in date_columns:
    df[col] = pd.to_datetime(df[col], format='%Y-%m-%d')
    
for col in date_columns:
    df[col] = df[col].dt.strftime("%B %d, %Y")
    
df.head()
# Out:
#    Unnamed: 0       accessionNumber         filingDate          reportDate  \
# 0           0  0001655887-24-000017       May 13, 2024      March 31, 2024
# 1           1  0001655887-24-000009     March 07, 2024   December 31, 2023
# 2           2  0001655887-23-000048  November 09, 2023  September 30, 2023
# 3           3  0001655887-23-000039    August 10, 2023       June 30, 2023
# 4           4  0001655887-23-000025       May 11, 2023      March 31, 2023
#
#          acceptanceDateTime  act  form fileNumber  filmNumber  items  \
# 0  2024-05-10T17:40:30.000Z   34  10-Q  814-01219    24936212    NaN
# 1  2024-03-06T19:19:00.000Z   34  10-K  814-01219    24727699    NaN
# 2  2023-11-09T16:58:33.000Z   34  10-Q  814-01219   231393518    NaN
# 3  2023-08-10T17:14:29.000Z   34  10-Q  814-01219   231160654    NaN
# 4  2023-05-11T16:06:55.000Z   34  10-Q  814-01219    23910979    NaN
#
#        size  isXBRL  isInlineXBRL    primaryDocument primaryDocDescription  \
# 0  28055386       1             1  obdc-20240331.htm                  10-Q
# 1  35559661       1             1  obdc-20231231.htm                  10-K
# 2  28991189       1             1  obdc-20230930.htm                  10-Q
# 3  27739370       1             1  obdc-20230630.htm                  10-Q
# 4  46704697       1             1  orcc-20230331.htm                  10-Q
#
#                                             fileLink  \
# 0  https://www.sec.gov/Archives/edgar/data/165588...
# 1  https://www.sec.gov/Archives/edgar/data/165588...
# 2  https://www.sec.gov/Archives/edgar/data/165588...
# 3  https://www.sec.gov/Archives/edgar/data/165588...
# 4  https://www.sec.gov/Archives/edgar/data/165588...
#
#                                          txtFileLink Reporting date
# 0  https://www.sec.gov/Archives/edgar/data/165588...     2024-03-31
# 1  https://www.sec.gov/Archives/edgar/data/165588...     2023-12-31
# 2  https://www.sec.gov/Archives/edgar/data/165588...     2023-09-30
# 3  https://www.sec.gov/Archives/edgar/data/165588...     2023-06-30
# 4  https://www.sec.gov/Archives/edgar/data/165588...     2023-03-31

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             29 non-null     int64
#  1   accessionNumber        29 non-null     object
#  2   filingDate             29 non-null     object
#  3   reportDate             29 non-null     object
#  4   acceptanceDateTime     29 non-null     object
#  5   act                    29 non-null     int64
#  6   form                   29 non-null     object
#  7   fileNumber             29 non-null     object
#  8   filmNumber             29 non-null     int64
#  9   items                  0 non-null      float64
#  10  size                   29 non-null     int64
#  11  isXBRL                 29 non-null     int64
#  12  isInlineXBRL           29 non-null     int64
#  13  primaryDocument        29 non-null     object
#  14  primaryDocDescription  29 non-null     object
#  15  fileLink               29 non-null     object
#  16  txtFileLink            29 non-null     object
#  17  Reporting date         29 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(6), object(10)
# memory usage: 4.2+ KB

# %%
# Drop extra columns
columns_to_drop = ['Unnamed: 0', 'acceptanceDateTime', 'act', 'fileNumber', 'filmNumber', 
                   'items', 'size', 'isXBRL', 'isInlineXBRL', 'Reporting date']
df.drop(columns_to_drop, axis=1, inplace=True)
df.head()
# Out:
#         accessionNumber         filingDate          reportDate  form  \
# 0  0001655887-24-000017       May 13, 2024      March 31, 2024  10-Q
# 1  0001655887-24-000009     March 07, 2024   December 31, 2023  10-K
# 2  0001655887-23-000048  November 09, 2023  September 30, 2023  10-Q
# 3  0001655887-23-000039    August 10, 2023       June 30, 2023  10-Q
# 4  0001655887-23-000025       May 11, 2023      March 31, 2023  10-Q
#
#      primaryDocument primaryDocDescription  \
# 0  obdc-20240331.htm                  10-Q
# 1  obdc-20231231.htm                  10-K
# 2  obdc-20230930.htm                  10-Q
# 3  obdc-20230630.htm                  10-Q
# 4  orcc-20230331.htm                  10-Q
#
#                                             fileLink  \
# 0  https://www.sec.gov/Archives/edgar/data/165588...
# 1  https://www.sec.gov/Archives/edgar/data/165588...
# 2  https://www.sec.gov/Archives/edgar/data/165588...
# 3  https://www.sec.gov/Archives/edgar/data/165588...
# 4  https://www.sec.gov/Archives/edgar/data/165588...
#
#                                          txtFileLink
# 0  https://www.sec.gov/Archives/edgar/data/165588...
# 1  https://www.sec.gov/Archives/edgar/data/165588...
# 2  https://www.sec.gov/Archives/edgar/data/165588...
# 3  https://www.sec.gov/Archives/edgar/data/165588...
# 4  https://www.sec.gov/Archives/edgar/data/165588...

# %%
# Last check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   accessionNumber        29 non-null     object
#  1   filingDate             29 non-null     object
#  2   reportDate             29 non-null     object
#  3   form                   29 non-null     object
#  4   primaryDocument        29 non-null     object
#  5   primaryDocDescription  29 non-null     object
#  6   fileLink               29 non-null     object
#  7   txtFileLink            29 non-null     object
# dtypes: object(8)
# memory usage: 1.9+ KB

# %% [markdown]
# ## Tables extraction

# %%
qtr_dates = []
for index, url in enumerate(df['fileLink']):
    response = requests.get(url, headers=headers)
    content = parse_and_trim(response.content, 'HTML')
    qtr_date = find_qrt_date(content)
    print(f'{index} - {url}')
    print(f'{qtr_date}')
#     qtr_dates.append(qtr_date.replace(',', '').strip())

# Add quarter date for each filing
# df['qtr_date'] = qtr_dates
# Out:
# For the quarterly period ended
# 0 - https://www.sec.gov/Archives/edgar/data/1655887/000165588724000017/obdc-20240331.htm
# December 31, 2023
# For the fiscal year ended
# 1 - https://www.sec.gov/Archives/edgar/data/1655887/000165588724000009/obdc-20231231.htm
# None
# For the quarterly period ended
# 2 - https://www.sec.gov/Archives/edgar/data/1655887/000165588723000048/obdc-20230930.htm
# March 31, 2022
# For the quarterly period ended
# 3 - https://www.sec.gov/Archives/edgar/data/1655887/000165588723000039/obdc-20230630.htm
# March 31, 2022
# For the quarterly period ended
# 4 - https://www.sec.gov/Archives/edgar/data/1655887/000165588723000025/orcc-20230331.htm
# March 31, 2022
# For the fiscal year ended
# 5 - https://www.sec.gov/Archives/edgar/data/1655887/000165588723000009/orcc-20221231.htm
# May 3, 2022
# For the quarterly period ended September 30, 2022
# 6 - https://www.sec.gov/Archives/edgar/data/1655887/000165588722000008/a01orccii-2022930x10q.htm
# September 30, 2022
# For the quarterly period ended June 30, 2022
# 7 - https://www.sec.gov/Archives/edgar/data/1655887/000165588722000006/a01orccii-2022630x10q.htm
# June 30, 2022
# For the quarterly period ended March 31, 2022
# 8 - https://www.sec.gov/Archives/edgar/data/1655887/000095017022009355/orccii_10q_0331-2022.htm
# March 31, 2022
# For the fiscal year ended December 31, 2021
# 9 - https://www.sec.gov/Archives/edgar/data/1655887/000095017022002917/orccii_10k_1231_2021.htm
# December 31, 2021
# For the quarterly period ended September 30, 2021
# 10 - https://www.sec.gov/Archives/edgar/data/1655887/000095017021003834/orccii_10q_0930-2021.htm
# September 30, 2021
# For the quarterly period ended June 30, 2021
# 11 - https://www.sec.gov/Archives/edgar/data/1655887/000156459021043121/orccii-10q_20210630.htm
# June 30, 2021
# For the quarterly period ended March 31, 2021
# 12 - https://www.sec.gov/Archives/edgar/data/1655887/000156459021026621/orccii-10q_20210331.htm
# March 31, 2021
# For the fiscal year ended December 31, 2020
# 13 - https://www.sec.gov/Archives/edgar/data/1655887/000156459021011045/orccii-10k_20201231.htm
# December 31, 2020
# For the quarterly period ended September 30, 2020
# 14 - https://www.sec.gov/Archives/edgar/data/1655887/000156459020053022/orccii-10q_20200930.htm
# September 30, 2020
# For the quarterly period ended June 30, 2020
# 15 - https://www.sec.gov/Archives/edgar/data/1655887/000156459020039301/orccii-10q_20200630.htm
# June 30, 2020
# For the quarterly period ended March 31, 2020
# 16 - https://www.sec.gov/Archives/edgar/data/1655887/000156459020024676/orccii-10q_20200331.htm
# March 31, 2020
# For the fiscal year ended December 31, 2019
# 17 - https://www.sec.gov/Archives/edgar/data/1655887/000156459020006523/orccii-10k_20191231.htm
# December 31, 2019
# For the quarterly period ended September 30, 2019
# 18 - https://www.sec.gov/Archives/edgar/data/1655887/000156459019040540/orccii-10q_20190930.htm
# September 30, 2019
# For the quarterly period ended June 30, 2019
# 19 - https://www.sec.gov/Archives/edgar/data/1655887/000156459019030152/orccii-10q_20190630.htm
# June 30, 2019
# For the quarterly period ended March 31, 2019
# 20 - https://www.sec.gov/Archives/edgar/data/1655887/000156459019017017/orccii-10q_20190331.htm
# March 31, 2019
# For the fiscal year ended December 31, 2018
# 21 - https://www.sec.gov/Archives/edgar/data/1655887/000156459019004958/orccii-10k_20181231.htm
# December 31, 2018
# For the quarterly period ended September 30, 2018
# 22 - https://www.sec.gov/Archives/edgar/data/1655887/000156459018027576/orccii-10q_20180930.htm
# September 30, 2018
# For the quarterly period ended June 30, 2018
# 23 - https://www.sec.gov/Archives/edgar/data/1655887/000156459018020092/orccii-10q_20180630.htm
# June 30, 2018
# For the quarterly period ended March 31, 2018
# 24 - https://www.sec.gov/Archives/edgar/data/1655887/000156459018011995/orccii-10q_20180331.htm
# March 31, 2018
# For the fiscal year ended December 31, 2017
# 25 - https://www.sec.gov/Archives/edgar/data/1655887/000156459018004298/orccii-10k_20171231.htm
# December 31, 2017
# For the quarterly period ended September 30, 2017
# 26 - https://www.sec.gov/Archives/edgar/data/1655887/000156459017022363/orccii-10q_20170930.htm
# September 30, 2017
# For the quarterly period ended June 30, 2017
# 27 - https://www.sec.gov/Archives/edgar/data/1655887/000156459017016651/orccii-10q_20170630.htm
# June 30, 2017
# For the quarterly period ended March 31, 2017
# 28 - https://www.sec.gov/Archives/edgar/data/1655887/000156459017009957/orccii-10q_20170331.htm
# March 31, 2017
